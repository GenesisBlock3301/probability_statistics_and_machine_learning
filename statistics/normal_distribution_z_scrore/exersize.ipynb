# %%
# https://github.com/codebasics/math-for-machine-learning/blob/main/3_normal_distribution/Exercise/exercise.md
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)
import seaborn as sn

# %%
df = pd.read_csv("bhp.csv")
df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
df.price_per_sqft.describe()
# Out:
# count    1.320000e+04
# mean     7.920337e+03
# std      1.067272e+05
# min      2.670000e+02
# 25%      4.267000e+03
# 50%      5.438000e+03
# 75%      7.317000e+03
# max      1.200000e+07
# Name: price_per_sqft, dtype: float64

# %%
plt.hist(df.price_per_sqft, bins=20, rwidth=0.8)
plt.xlabel("Price per square ft")
plt.ylabel("Count")
plt.show()

# %%
plt.hist(df.price_per_sqft, bins=20, rwidth=0.8)
plt.xlabel("Price per square ft")
plt.ylabel("Count")
plt.yscale("log")
plt.show()

# %%
low, high = df.price_per_sqft.quantile([0.001,0.999])
low, high
# Out:
# (1366.184, 50959.36200000098)

# %%
outliers = df[(df.price_per_sqft < low) | (df.price_per_sqft > high)]
outliers
# outliers.shape
# """here we can see 1365 is too lower price per sqft"""
# Out:
#                 location       size  total_sqft  bath   price  bhk  \
# 345                other  3 Bedroom        11.0   3.0    74.0    3
# 665            Yelahanka      3 BHK     35000.0   3.0   130.0    3
# 798                other  4 Bedroom     10961.0   4.0    80.0    4
# 1005               other      1 BHK        15.0   1.0    30.0    1
# 1106               other  5 Bedroom        24.0   2.0   150.0    5
# 1867               other  3 Bedroom     52272.0   2.0   140.0    3
# 2392               other  4 Bedroom      2000.0   3.0    25.0    4
# 3934               other      1 BHK      1500.0   1.0    19.5    1
# 4044      Sarjapur  Road  4 Bedroom         1.0   4.0   120.0    4
# 4924               other      7 BHK         5.0   7.0   115.0    7
# 5343               other      9 BHK     42000.0   8.0   175.0    9
# 5417              Ulsoor      4 BHK     36000.0   4.0   450.0    4
# 5597            JP Nagar      2 BHK      1100.0   1.0    15.0    2
# ...

# %%
df2 = df[(df.price_per_sqft > low) & (df.price_per_sqft < high)]
df2
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
# In above outliers 28 outliers reduce

# %%
max_limit = df2.price_per_sqft.mean() + 4*df2.price_per_sqft.std()
low_limit = df2.price_per_sqft.mean() - 4*df2.price_per_sqft.std()
low_limit, max_limit
# Out:
# (-9900.429065502582, 23227.73653589432)

# %%
remove_count = df2[(df2.price_per_sqft < low_limit) | (df2.price_per_sqft > max_limit)]
remove_count.shape, df2.shape
# Out:
# ((125, 7), (13172, 7))

# %%
df3 = df2[(df2.price_per_sqft > low_limit) & (df2.price_per_sqft < max_limit)]
df3.shape
# Out:
# (13047, 7)

# %%
number_of_outlier_remove = df2.shape[0] - df3.shape[0]
number_of_outlier_remove
# Out:
# 125

# %%
plt.hist(df3.price_per_sqft, bins=20, rwidth=0.8)
plt.xlabel("Price per square ft")
plt.ylabel("Count")
plt.show()

# %%
df3.price_per_sqft.describe()
# Out:
# count    13047.000000
# mean      6449.328045
# std       3487.670005
# min       1379.000000
# 25%       4259.000000
# 50%       5415.000000
# 75%       7222.000000
# max      23214.000000
# Name: price_per_sqft, dtype: float64

# %%
sn.histplot(df3.price_per_sqft, kde=True)
# Out:
# <AxesSubplot: xlabel='price_per_sqft', ylabel='Count'>

# %%
df2["zscore"] = (df2.price_per_sqft - df2.price_per_sqft.mean())/df2.price_per_sqft.std()
df2["zscore"]
# Out:
# /tmp/ipykernel_12192/1496355708.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["zscore"] = (df2.price_per_sqft - df2.price_per_sqft.mean())/df2.price_per_sqft.std()
# 0       -0.715923
# 1       -0.494722
# 2       -0.569583
# 3       -0.101099
# 4       -0.582864
#            ...
# 13195    0.006121
# 13196    1.073973
# 13197   -0.339446
# 13198    0.903967
# 13199   -0.862989
# Name: zscore, Length: 13172, dtype: float64

# %%
outliers_z = df2[(df2.zscore < -4) | (df2.zscore>4)]
# outliers_z.shape
df2.shape
# Out:
# (13172, 8)

# %%
df4 = df2[(df2.zscore>-4)&(df2.zscore<4)]
df4.shape
# Out:
# (13047, 8)

# %%
df2.shape[0] - df4.shape[0]
# Out:
# 125
